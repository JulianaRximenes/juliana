# %%
import random

lista_palavra = ['python','progamacao','computador', 'notebook', 'software', 'openai']

palavras = random.choice(lista_palavra)
letras_corretas = []
letras_erradas = []
tentativas = 6

while True:
    palavra_escondida =''
    for letra in palavras:
        if letra in letras_corretas:
            palavra_escondida +=letra
        else:
            palavra_escondida += '_'

    print('palavra:', palavra_escondida)
    print('letra erradas', letras_erradas)
    print('tentativas restantes:', tentativas)

    if palavra_escondida == palavras:
        print('voce acertou')
        break
    elif tentativas ==0:
        print(f'vc perdeu, a palavra era: {palavras}')
        break
    letra_usuario= input('digite uma letra').lower()
    if letra_usuario in palavras:
        print('letra correta')
        letras_corretas.append(letra_usuario)
    else:
        print('letra incorreta')
        letras_erradas.append(letra_usuario)
        tentativas -= 1
# Out:
# palavra: __________
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: ______a___
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: _o____a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: _o____a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: co____a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: co____a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: com___a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: com___a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: comp__a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: compu_a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: compu_a_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# palavra: computa_o_
# letra erradas []
# tentativas restantes: 6
# letra correta
# ...
